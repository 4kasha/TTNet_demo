# %% [markdown]
# video link
#
# https://www.youtube.com/watch?v=G92cKxANHjQ (1080p60)
#
# https://www.youtube.com/watch?v=q_cYh3uJe_Q (1080p60)
#
# https://www.youtube.com/watch?v=e5etkwuFPQY (1080p)

# %% [markdown]
# # Download

# %%
# !pip install pytube3

# %%
from pytube import YouTube

url = input("https://www.youtube.com/watch?v=G92cKxANHjQ")
# Out:
# https://www.youtube.com/watch?v=G92cKxANHjQhttps://www.youtube.com/watch?v=G92cKxANHjQ

# %%
print(*YouTube(url).streams.all(), sep="\n")
# Out:
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="313" mime_type="video/webm" res="2160p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="315" mime_type="video/webm" res="2160p" fps="60fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="271" mime_type="video/webm" res="1440p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="308" mime_type="video/webm" res="1440p" fps="60fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# ...

# %%
itag = int(input("299"))
YouTube(url).streams.get_by_itag(itag).download(r"./tennis")
# Out:
# 299299
# '/content/drive/My Drive/Data_Videos/youtube/./tennis/Brandon Nakashima  IW Practice and Challenger SF (Mar 7 2020) 4k 60fps.mp4'

# %% [markdown]
# #clip

# %%
cd tennis/
# Out:
# /content/drive/My Drive/Data_Videos/youtube/tennis

# %%
# !ffmpeg -ss 00:01:18 -i tennis60fps.mp4 -ss 0 -t 00:00:24 -c:v copy test.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
